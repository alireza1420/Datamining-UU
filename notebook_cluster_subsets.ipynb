# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("European_citiznes_rsvp_eu_clean.csv")
df.head()
# Out:
#    COUNTRY    YEAR  SEX  circulatory_diseases  youth_unemployment_rate  \
# 0  Austria  1991.0  ALL               3051.58                     3.72
# 1  Austria  1992.0  ALL               3002.43                     4.13
# 2  Austria  1995.0  ALL               2844.85                     5.91
# 3  Austria  1999.0  ALL               2646.71                     5.93
# 4  Austria  2006.0  ALL               1834.76                     9.75
#
#    gross_national_income  unemployment_rate  regular_daily_smokers  \
# 0                21810.0               3.46                   27.5
# 1                24520.0               3.61                   35.0
# 2                28190.0               3.66                   24.0
# 3                27080.0               3.72                   36.3
# 4                41500.0               5.30                   23.2
#
#    average_fruit_vegtable_ppd  fat_available_ppd  adult_overweight  \
# 0                      209.10             159.23             40.09
# 1                      212.51             161.42             40.40
# 2                      200.16             152.79             41.33
# 3                      205.56             157.23             42.58
# 4                      238.95             162.30             44.27
#
#    self_injury  average_number_of_calories_available_per_person_per_day  \
# 0         1.25                                             3556.0
# 1         1.44                                             3546.0
# 2         1.04                                             3510.0
# 3         0.83                                             3673.0
# 4         0.79                                             3719.0
#
#    total_hospital_beds  Ischaemic_heart_diseas  life_expectancy  \
# 0              70143.0                   38.53            75.95
# 1              69268.0                   37.38            76.13
# 2              67853.0                   35.48            76.97
# 3              64594.0                   30.69            78.13
# 4              63354.0                   18.06            80.19
#
#    alcahol_consumption_liter_per_capita  protein_ppd
# 0                                 14.10       103.15
# 1                                 13.60       103.95
# 2                                 13.40       100.54
# 3                                 12.80       105.49
# 4                                 12.58       101.46

# %%
# filterByYear = df[df["YEAR"]==2000]
filterByYear = df
filterByYear[["COUNTRY","YEAR","life_expectancy"]].head()
# Out:
#    COUNTRY    YEAR  life_expectancy
# 0  Austria  1991.0            75.95
# 1  Austria  1992.0            76.13
# 2  Austria  1995.0            76.97
# 3  Austria  1999.0            78.13
# 4  Austria  2006.0            80.19

# %%
from sklearn.cluster import KMeans
import numpy as np

X = np.array([[1, 2], [1, 4], [1, 0],
              [10, 2], [10, 4], [10, 0]])
kmeans = KMeans(n_clusters=3, random_state=0, n_init="auto").fit(filterByYear[["life_expectancy","life_expectancy"]])
kmeans.labels_
#kmeans.predict([[0, 0], [12, 3]])
kmeans.cluster_centers_
# Out:
# array([[72.42227273, 72.42227273],
#        [77.33650943, 77.33650943],
#        [80.7592381 , 80.7592381 ]])

# %%
from sklearn.cluster import KMeans

y_pred = KMeans(n_clusters=3, random_state=0, n_init="auto").fit(filterByYear[["YEAR","life_expectancy"]])
y_pred.predict(filterByYear[["YEAR","life_expectancy"]])
filterByYear["cluster"] = y_pred.labels_
filterByYear[["COUNTRY","YEAR","life_expectancy","cluster"]].head()

y_pred.cluster_centers_[:,1]
# y_pred.labels_
# Out:
# array([76.20710145, 77.36438776, 79.81784091])

# %%
fig, ax = plt.subplots()
ax.scatter(filterByYear["life_expectancy"], filterByYear["life_expectancy"], c=filterByYear["cluster"])
ax.scatter(y_pred.cluster_centers_[:,1], y_pred.cluster_centers_[:,1], c='red', marker='+')
ax.grid(True)

plt.show()

# %%
forExport = filterByYear.copy()
labels = ['LOW', 'LOW-MEDIUM','MEDIUM', 'MEDIUM-HIGH', 'HIGH']

def clusterToLabel(centers):
    labelMap = []
    # for c in arr:
    # centers = np.array([2.5, -1.2, 0.7])  # cluster 0,1,2
    sorted_labels = np.argsort(centers)       # array([1,2,0]) low->high
    rank_map = {int(lbl): rank for rank, lbl in enumerate(sorted_labels, start=0)}  # {1:1,2:2,0:3}
    # labels: array of shape (n_samples,) with cluster ids
    labels = np.array([0,0,1,2,1,2])
    # print(rank_map)
    return rank_map

clusterToLabel([0.5, 3, 2])
# Out:
# {0: 0, 2: 1, 1: 2}

# %%
for series_name, series in df.items():
    if series_name == "COUNTRY" or series_name == "SEX" or series_name == "YEAR":
        continue
    print(series_name)
    y_pred = KMeans(n_clusters=5).fit(filterByYear[[series_name,series_name]])
    y_pred.predict(filterByYear[[series_name,series_name]])
    y_pred.cluster_centers_
    filterByYear["cluster"] = y_pred.labels_
    filterByYear[["COUNTRY","YEAR",series_name,"cluster"]].head()

    fig, ax = plt.subplots()
    ax.scatter(filterByYear[series_name], filterByYear[series_name], c=filterByYear["cluster"])
    ax.scatter(y_pred.cluster_centers_[:,1], y_pred.cluster_centers_[:,1], c='red', marker='+')
    ax.grid(True)
    ax.set_title(series_name)

    plt.show()

    relab = clusterToLabel(y_pred.cluster_centers_[:,1])

    for i in range(len(filterByYear[series_name])):
        forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]

forExport
# Out:
# circulatory_diseases
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# youth_unemployment_rate
# /tmp/ipykernel_30780/1473812822.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /tmp/ipykernel_30780/1473812822.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# gross_national_income
# /tmp/ipykernel_30780/1473812822.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# unemployment_rate
# /tmp/ipykernel_30780/1473812822.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# regular_daily_smokers
# /tmp/ipykernel_30780/1473812822.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# average_fruit_vegtable_ppd
# fat_available_ppd
# /tmp/ipykernel_30780/1473812822.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /tmp/ipykernel_30780/1473812822.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# adult_overweight
# /tmp/ipykernel_30780/1473812822.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# self_injury
# /tmp/ipykernel_30780/1473812822.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# average_number_of_calories_available_per_person_per_day
# /tmp/ipykernel_30780/1473812822.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# total_hospital_beds
# /tmp/ipykernel_30780/1473812822.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Ischaemic_heart_diseas
# /tmp/ipykernel_30780/1473812822.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# life_expectancy
# /tmp/ipykernel_30780/1473812822.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# alcahol_consumption_liter_per_capita
# /tmp/ipykernel_30780/1473812822.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# protein_ppd
# /tmp/ipykernel_30780/1473812822.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# cluster
# /tmp/ipykernel_30780/1473812822.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(forExport['cluster'][i])]
#      COUNTRY    YEAR  SEX circulatory_diseases youth_unemployment_rate  \
# 0    Austria  1991.0  ALL           LOW-MEDIUM             MEDIUM-HIGH
# 1    Austria  1992.0  ALL           LOW-MEDIUM             MEDIUM-HIGH
# 2    Austria  1995.0  ALL           LOW-MEDIUM             MEDIUM-HIGH
# 3    Austria  1999.0  ALL           LOW-MEDIUM             MEDIUM-HIGH
# 4    Austria  2006.0  ALL          MEDIUM-HIGH              LOW-MEDIUM
# ..       ...     ...  ...                  ...                     ...
# 250   Sweden  2010.0  ALL                  LOW                     LOW
# 251   Sweden  2011.0  ALL                  LOW                     LOW
# 252   Sweden  2012.0  ALL                  LOW                     LOW
# 253   Sweden  2013.0  ALL                  LOW                     LOW
# 254   Sweden  2014.0  ALL                  LOW                     LOW
#
#     gross_national_income unemployment_rate regular_daily_smokers  \
# 0                     LOW        LOW-MEDIUM            LOW-MEDIUM
# 1                     LOW        LOW-MEDIUM            LOW-MEDIUM
# 2                     LOW        LOW-MEDIUM            LOW-MEDIUM
# 3                     LOW        LOW-MEDIUM            LOW-MEDIUM
# 4                  MEDIUM       MEDIUM-HIGH           MEDIUM-HIGH
# ..                    ...               ...                   ...
# 250            LOW-MEDIUM              HIGH                  HIGH
# 251            LOW-MEDIUM              HIGH                  HIGH
# 252            LOW-MEDIUM              HIGH                  HIGH
# 253            LOW-MEDIUM              HIGH                  HIGH
# 254            LOW-MEDIUM              HIGH                  HIGH
#
#     average_fruit_vegtable_ppd fat_available_ppd adult_overweight  \
# 0                       MEDIUM              HIGH      MEDIUM-HIGH
# 1                       MEDIUM              HIGH      MEDIUM-HIGH
# 2                       MEDIUM              HIGH      MEDIUM-HIGH
# 3                       MEDIUM              HIGH      MEDIUM-HIGH
# 4                   LOW-MEDIUM        LOW-MEDIUM       LOW-MEDIUM
# ..                         ...               ...              ...
# 250                       HIGH            MEDIUM           MEDIUM
# 251                       HIGH            MEDIUM           MEDIUM
# 252                       HIGH            MEDIUM           MEDIUM
# 253                       HIGH            MEDIUM           MEDIUM
# 254                       HIGH            MEDIUM           MEDIUM
#
#      self_injury average_number_of_calories_available_per_person_per_day  \
# 0            LOW                                         LOW-MEDIUM
# 1            LOW                                         LOW-MEDIUM
# 2            LOW                                         LOW-MEDIUM
# 3            LOW                                         LOW-MEDIUM
# 4    MEDIUM-HIGH                                             MEDIUM
# ..           ...                                                ...
# 250       MEDIUM                                        MEDIUM-HIGH
# 251       MEDIUM                                        MEDIUM-HIGH
# 252       MEDIUM                                        MEDIUM-HIGH
# 253       MEDIUM                                        MEDIUM-HIGH
# 254       MEDIUM                                        MEDIUM-HIGH
#
#     total_hospital_beds Ischaemic_heart_diseas life_expectancy  \
# 0            LOW-MEDIUM                 MEDIUM     MEDIUM-HIGH
# 1            LOW-MEDIUM                 MEDIUM     MEDIUM-HIGH
# 2            LOW-MEDIUM                 MEDIUM     MEDIUM-HIGH
# 3            LOW-MEDIUM                 MEDIUM     MEDIUM-HIGH
# 4           MEDIUM-HIGH                    LOW             LOW
# ..                  ...                    ...             ...
# 250              MEDIUM             LOW-MEDIUM      LOW-MEDIUM
# 251              MEDIUM             LOW-MEDIUM      LOW-MEDIUM
# 252              MEDIUM             LOW-MEDIUM      LOW-MEDIUM
# 253              MEDIUM             LOW-MEDIUM      LOW-MEDIUM
# 254              MEDIUM             LOW-MEDIUM      LOW-MEDIUM
#
#     alcahol_consumption_liter_per_capita  protein_ppd      cluster
# 0                                 MEDIUM       MEDIUM  MEDIUM-HIGH
# 1                                 MEDIUM       MEDIUM  MEDIUM-HIGH
# 2                                 MEDIUM       MEDIUM  MEDIUM-HIGH
# 3                                 MEDIUM       MEDIUM  MEDIUM-HIGH
# 4                                    LOW  MEDIUM-HIGH   LOW-MEDIUM
# ..                                   ...          ...          ...
# 250                          MEDIUM-HIGH          LOW          LOW
# 251                          MEDIUM-HIGH          LOW          LOW
# 252                          MEDIUM-HIGH          LOW          LOW
# 253                          MEDIUM-HIGH          LOW          LOW
# 254                          MEDIUM-HIGH          LOW          LOW
#
# [255 rows x 19 columns]

# %%
rename_map = {
    "life_expectancy": "LIFEEXP",
    "average_number_of_calories_available_per_person_per_day": "CALORIES",
    "unemployment_rate": "UNEMP",
    "regular_daily_smokers": "SMOKING",
    "adult_overweight": "OVERWT",
    "alcahol_consumption_liter_per_capita": "ALCOHOL",
    "fat_available_ppd": "FAT",
    "protein_ppd": "PROTEIN",
    "average_fruit_vegtable_ppd": "FRUITVEG",
    "annual_income": "ANNUALINCOME",  
    "youth_unemployment_rate": "YOUTH_UNEMP_RATE",  
    "Ischaemic_heart_diseas": "HEARTDISEAS",  
    "circulatory_diseases": "CIRCULATORYDISEAS",  
    "self_injury": "SELFINJURY",  
    "total_hospital_beds": "TOTALHOSPBED",  
    "gross_national_income": "GROSS_NATIONAL_INCOME"
}

# item_cols = [c+"_bin" for c in cols_to_bin]
# print(item_cols)

forExport = forExport.rename(columns=rename_map)

# df = pd.DataFrame({"z":["a","a"], "zz":["b","c"]}, index=[1,2])

# Option 1 — transform all columns to "col=val" strings
# df_transformed = df.apply(lambda col: col.index.map(lambda i, c=col.name: f"{c}={col.loc[i]}"))
# but simpler:
forExport2 = forExport.apply(lambda col: col.map(lambda v, name=col.name: f"{name}={v}")).copy()

print(forExport2)

# 1 transaction = one (COUNTRY, YEAR)
tx_df = (forExport2.sort_values(["COUNTRY","YEAR"])
           .drop_duplicates(subset=["COUNTRY","YEAR"]))


transactions = forExport2#tx_df.apply(row_to_items, axis=1).tolist()
transactions = transactions.drop(columns=["COUNTRY","YEAR","SEX","cluster"])
num_records = len(transactions)
# print(transactions)
print("Transactions:", num_records)

pd.DataFrame(transactions).to_csv("rules_stat_cluster_new.csv", index=False)
# Out:
#              COUNTRY         YEAR      SEX              CIRCULATORYDISEAS  \
# 0    COUNTRY=Austria  YEAR=1991.0  SEX=ALL   CIRCULATORYDISEAS=LOW-MEDIUM
# 1    COUNTRY=Austria  YEAR=1992.0  SEX=ALL   CIRCULATORYDISEAS=LOW-MEDIUM
# 2    COUNTRY=Austria  YEAR=1995.0  SEX=ALL   CIRCULATORYDISEAS=LOW-MEDIUM
# 3    COUNTRY=Austria  YEAR=1999.0  SEX=ALL   CIRCULATORYDISEAS=LOW-MEDIUM
# 4    COUNTRY=Austria  YEAR=2006.0  SEX=ALL  CIRCULATORYDISEAS=MEDIUM-HIGH
# ..               ...          ...      ...                            ...
# 250   COUNTRY=Sweden  YEAR=2010.0  SEX=ALL          CIRCULATORYDISEAS=LOW
# 251   COUNTRY=Sweden  YEAR=2011.0  SEX=ALL          CIRCULATORYDISEAS=LOW
# 252   COUNTRY=Sweden  YEAR=2012.0  SEX=ALL          CIRCULATORYDISEAS=LOW
# 253   COUNTRY=Sweden  YEAR=2013.0  SEX=ALL          CIRCULATORYDISEAS=LOW
# 254   COUNTRY=Sweden  YEAR=2014.0  SEX=ALL          CIRCULATORYDISEAS=LOW
#
#                  YOUTH_UNEMP_RATE             GROSS_NATIONAL_INCOME  \
# 0    YOUTH_UNEMP_RATE=MEDIUM-HIGH         GROSS_NATIONAL_INCOME=LOW
# 1    YOUTH_UNEMP_RATE=MEDIUM-HIGH         GROSS_NATIONAL_INCOME=LOW
# 2    YOUTH_UNEMP_RATE=MEDIUM-HIGH         GROSS_NATIONAL_INCOME=LOW
# 3    YOUTH_UNEMP_RATE=MEDIUM-HIGH         GROSS_NATIONAL_INCOME=LOW
# 4     YOUTH_UNEMP_RATE=LOW-MEDIUM      GROSS_NATIONAL_INCOME=MEDIUM
# ..                            ...                               ...
# 250          YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=LOW-MEDIUM
# 251          YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=LOW-MEDIUM
# 252          YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=LOW-MEDIUM
# 253          YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=LOW-MEDIUM
# 254          YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=LOW-MEDIUM
#
#                  UNEMP              SMOKING             FRUITVEG  \
# 0     UNEMP=LOW-MEDIUM   SMOKING=LOW-MEDIUM      FRUITVEG=MEDIUM
# 1     UNEMP=LOW-MEDIUM   SMOKING=LOW-MEDIUM      FRUITVEG=MEDIUM
# 2     UNEMP=LOW-MEDIUM   SMOKING=LOW-MEDIUM      FRUITVEG=MEDIUM
# 3     UNEMP=LOW-MEDIUM   SMOKING=LOW-MEDIUM      FRUITVEG=MEDIUM
# 4    UNEMP=MEDIUM-HIGH  SMOKING=MEDIUM-HIGH  FRUITVEG=LOW-MEDIUM
# ..                 ...                  ...                  ...
# 250         UNEMP=HIGH         SMOKING=HIGH        FRUITVEG=HIGH
# 251         UNEMP=HIGH         SMOKING=HIGH        FRUITVEG=HIGH
# 252         UNEMP=HIGH         SMOKING=HIGH        FRUITVEG=HIGH
# 253         UNEMP=HIGH         SMOKING=HIGH        FRUITVEG=HIGH
# 254         UNEMP=HIGH         SMOKING=HIGH        FRUITVEG=HIGH
#
#                 FAT              OVERWT              SELFINJURY  \
# 0          FAT=HIGH  OVERWT=MEDIUM-HIGH          SELFINJURY=LOW
# 1          FAT=HIGH  OVERWT=MEDIUM-HIGH          SELFINJURY=LOW
# 2          FAT=HIGH  OVERWT=MEDIUM-HIGH          SELFINJURY=LOW
# 3          FAT=HIGH  OVERWT=MEDIUM-HIGH          SELFINJURY=LOW
# 4    FAT=LOW-MEDIUM   OVERWT=LOW-MEDIUM  SELFINJURY=MEDIUM-HIGH
# ..              ...                 ...                     ...
# 250      FAT=MEDIUM       OVERWT=MEDIUM       SELFINJURY=MEDIUM
# 251      FAT=MEDIUM       OVERWT=MEDIUM       SELFINJURY=MEDIUM
# 252      FAT=MEDIUM       OVERWT=MEDIUM       SELFINJURY=MEDIUM
# 253      FAT=MEDIUM       OVERWT=MEDIUM       SELFINJURY=MEDIUM
# 254      FAT=MEDIUM       OVERWT=MEDIUM       SELFINJURY=MEDIUM
#
#                  CALORIES              TOTALHOSPBED             HEARTDISEAS  \
# 0     CALORIES=LOW-MEDIUM   TOTALHOSPBED=LOW-MEDIUM      HEARTDISEAS=MEDIUM
# 1     CALORIES=LOW-MEDIUM   TOTALHOSPBED=LOW-MEDIUM      HEARTDISEAS=MEDIUM
# 2     CALORIES=LOW-MEDIUM   TOTALHOSPBED=LOW-MEDIUM      HEARTDISEAS=MEDIUM
# 3     CALORIES=LOW-MEDIUM   TOTALHOSPBED=LOW-MEDIUM      HEARTDISEAS=MEDIUM
# 4         CALORIES=MEDIUM  TOTALHOSPBED=MEDIUM-HIGH         HEARTDISEAS=LOW
# ..                    ...                       ...                     ...
# 250  CALORIES=MEDIUM-HIGH       TOTALHOSPBED=MEDIUM  HEARTDISEAS=LOW-MEDIUM
# 251  CALORIES=MEDIUM-HIGH       TOTALHOSPBED=MEDIUM  HEARTDISEAS=LOW-MEDIUM
# 252  CALORIES=MEDIUM-HIGH       TOTALHOSPBED=MEDIUM  HEARTDISEAS=LOW-MEDIUM
# 253  CALORIES=MEDIUM-HIGH       TOTALHOSPBED=MEDIUM  HEARTDISEAS=LOW-MEDIUM
# 254  CALORIES=MEDIUM-HIGH       TOTALHOSPBED=MEDIUM  HEARTDISEAS=LOW-MEDIUM
#
#                  LIFEEXP              ALCOHOL              PROTEIN  \
# 0    LIFEEXP=MEDIUM-HIGH       ALCOHOL=MEDIUM       PROTEIN=MEDIUM
# 1    LIFEEXP=MEDIUM-HIGH       ALCOHOL=MEDIUM       PROTEIN=MEDIUM
# 2    LIFEEXP=MEDIUM-HIGH       ALCOHOL=MEDIUM       PROTEIN=MEDIUM
# 3    LIFEEXP=MEDIUM-HIGH       ALCOHOL=MEDIUM       PROTEIN=MEDIUM
# 4            LIFEEXP=LOW          ALCOHOL=LOW  PROTEIN=MEDIUM-HIGH
# ..                   ...                  ...                  ...
# 250   LIFEEXP=LOW-MEDIUM  ALCOHOL=MEDIUM-HIGH          PROTEIN=LOW
# 251   LIFEEXP=LOW-MEDIUM  ALCOHOL=MEDIUM-HIGH          PROTEIN=LOW
# 252   LIFEEXP=LOW-MEDIUM  ALCOHOL=MEDIUM-HIGH          PROTEIN=LOW
# 253   LIFEEXP=LOW-MEDIUM  ALCOHOL=MEDIUM-HIGH          PROTEIN=LOW
# 254   LIFEEXP=LOW-MEDIUM  ALCOHOL=MEDIUM-HIGH          PROTEIN=LOW
#
#                  cluster
# 0    cluster=MEDIUM-HIGH
# 1    cluster=MEDIUM-HIGH
# 2    cluster=MEDIUM-HIGH
# 3    cluster=MEDIUM-HIGH
# 4     cluster=LOW-MEDIUM
# ..                   ...
# 250          cluster=LOW
# 251          cluster=LOW
# 252          cluster=LOW
# 253          cluster=LOW
# 254          cluster=LOW
#
# [255 rows x 19 columns]
# Transactions: 255

# %%
tt = forExport2
tt.loc[tt['COUNTRY'] == "COUNTRY=Denmark"]
# Out:
#             COUNTRY         YEAR      SEX              CIRCULATORYDISEAS  \
# 44  COUNTRY=Denmark  YEAR=1997.0  SEX=ALL   CIRCULATORYDISEAS=LOW-MEDIUM
# 45  COUNTRY=Denmark  YEAR=1998.0  SEX=ALL   CIRCULATORYDISEAS=LOW-MEDIUM
# 46  COUNTRY=Denmark  YEAR=1999.0  SEX=ALL   CIRCULATORYDISEAS=LOW-MEDIUM
# 47  COUNTRY=Denmark  YEAR=2000.0  SEX=ALL  CIRCULATORYDISEAS=MEDIUM-HIGH
# 48  COUNTRY=Denmark  YEAR=2001.0  SEX=ALL  CIRCULATORYDISEAS=MEDIUM-HIGH
# 49  COUNTRY=Denmark  YEAR=2002.0  SEX=ALL  CIRCULATORYDISEAS=MEDIUM-HIGH
# 50  COUNTRY=Denmark  YEAR=2003.0  SEX=ALL  CIRCULATORYDISEAS=MEDIUM-HIGH
# 51  COUNTRY=Denmark  YEAR=2004.0  SEX=ALL  CIRCULATORYDISEAS=MEDIUM-HIGH
# 52  COUNTRY=Denmark  YEAR=2005.0  SEX=ALL  CIRCULATORYDISEAS=MEDIUM-HIGH
# 53  COUNTRY=Denmark  YEAR=2006.0  SEX=ALL  CIRCULATORYDISEAS=MEDIUM-HIGH
# 54  COUNTRY=Denmark  YEAR=2007.0  SEX=ALL  CIRCULATORYDISEAS=MEDIUM-HIGH
# 55  COUNTRY=Denmark  YEAR=2008.0  SEX=ALL          CIRCULATORYDISEAS=LOW
# 56  COUNTRY=Denmark  YEAR=2009.0  SEX=ALL          CIRCULATORYDISEAS=LOW
# 57  COUNTRY=Denmark  YEAR=2010.0  SEX=ALL          CIRCULATORYDISEAS=LOW
# 58  COUNTRY=Denmark  YEAR=2011.0  SEX=ALL          CIRCULATORYDISEAS=LOW
# 59  COUNTRY=Denmark  YEAR=2013.0  SEX=ALL          CIRCULATORYDISEAS=LOW
# 60  COUNTRY=Denmark  YEAR=2014.0  SEX=ALL          CIRCULATORYDISEAS=LOW
# 61  COUNTRY=Denmark  YEAR=2015.0  SEX=ALL          CIRCULATORYDISEAS=LOW
#
#                 YOUTH_UNEMP_RATE             GROSS_NATIONAL_INCOME  \
# 44  YOUTH_UNEMP_RATE=MEDIUM-HIGH         GROSS_NATIONAL_INCOME=LOW
# 45  YOUTH_UNEMP_RATE=MEDIUM-HIGH         GROSS_NATIONAL_INCOME=LOW
# 46  YOUTH_UNEMP_RATE=MEDIUM-HIGH         GROSS_NATIONAL_INCOME=LOW
# 47   YOUTH_UNEMP_RATE=LOW-MEDIUM      GROSS_NATIONAL_INCOME=MEDIUM
# 48   YOUTH_UNEMP_RATE=LOW-MEDIUM      GROSS_NATIONAL_INCOME=MEDIUM
# 49   YOUTH_UNEMP_RATE=LOW-MEDIUM      GROSS_NATIONAL_INCOME=MEDIUM
# 50   YOUTH_UNEMP_RATE=LOW-MEDIUM      GROSS_NATIONAL_INCOME=MEDIUM
# 51   YOUTH_UNEMP_RATE=LOW-MEDIUM      GROSS_NATIONAL_INCOME=MEDIUM
# 52   YOUTH_UNEMP_RATE=LOW-MEDIUM      GROSS_NATIONAL_INCOME=MEDIUM
# 53   YOUTH_UNEMP_RATE=LOW-MEDIUM      GROSS_NATIONAL_INCOME=MEDIUM
# 54   YOUTH_UNEMP_RATE=LOW-MEDIUM      GROSS_NATIONAL_INCOME=MEDIUM
# 55          YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=LOW-MEDIUM
# 56          YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=LOW-MEDIUM
# 57          YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=LOW-MEDIUM
# 58          YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=LOW-MEDIUM
# 59          YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=LOW-MEDIUM
# 60          YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=LOW-MEDIUM
# 61          YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=LOW-MEDIUM
#
#                 UNEMP              SMOKING             FRUITVEG  \
# 44   UNEMP=LOW-MEDIUM   SMOKING=LOW-MEDIUM      FRUITVEG=MEDIUM
# 45   UNEMP=LOW-MEDIUM   SMOKING=LOW-MEDIUM      FRUITVEG=MEDIUM
# 46   UNEMP=LOW-MEDIUM   SMOKING=LOW-MEDIUM      FRUITVEG=MEDIUM
# 47  UNEMP=MEDIUM-HIGH  SMOKING=MEDIUM-HIGH  FRUITVEG=LOW-MEDIUM
# 48  UNEMP=MEDIUM-HIGH  SMOKING=MEDIUM-HIGH  FRUITVEG=LOW-MEDIUM
# 49  UNEMP=MEDIUM-HIGH  SMOKING=MEDIUM-HIGH  FRUITVEG=LOW-MEDIUM
# 50  UNEMP=MEDIUM-HIGH  SMOKING=MEDIUM-HIGH  FRUITVEG=LOW-MEDIUM
# 51  UNEMP=MEDIUM-HIGH  SMOKING=MEDIUM-HIGH  FRUITVEG=LOW-MEDIUM
# 52  UNEMP=MEDIUM-HIGH  SMOKING=MEDIUM-HIGH  FRUITVEG=LOW-MEDIUM
# 53  UNEMP=MEDIUM-HIGH  SMOKING=MEDIUM-HIGH  FRUITVEG=LOW-MEDIUM
# 54  UNEMP=MEDIUM-HIGH  SMOKING=MEDIUM-HIGH  FRUITVEG=LOW-MEDIUM
# 55         UNEMP=HIGH         SMOKING=HIGH        FRUITVEG=HIGH
# 56         UNEMP=HIGH         SMOKING=HIGH        FRUITVEG=HIGH
# 57         UNEMP=HIGH         SMOKING=HIGH        FRUITVEG=HIGH
# 58         UNEMP=HIGH         SMOKING=HIGH        FRUITVEG=HIGH
# 59         UNEMP=HIGH         SMOKING=HIGH        FRUITVEG=HIGH
# 60         UNEMP=HIGH         SMOKING=HIGH        FRUITVEG=HIGH
# 61         UNEMP=HIGH         SMOKING=HIGH        FRUITVEG=HIGH
#
#                FAT              OVERWT              SELFINJURY  \
# 44        FAT=HIGH  OVERWT=MEDIUM-HIGH          SELFINJURY=LOW
# 45        FAT=HIGH  OVERWT=MEDIUM-HIGH          SELFINJURY=LOW
# 46        FAT=HIGH  OVERWT=MEDIUM-HIGH          SELFINJURY=LOW
# 47  FAT=LOW-MEDIUM   OVERWT=LOW-MEDIUM  SELFINJURY=MEDIUM-HIGH
# 48  FAT=LOW-MEDIUM   OVERWT=LOW-MEDIUM  SELFINJURY=MEDIUM-HIGH
# 49  FAT=LOW-MEDIUM   OVERWT=LOW-MEDIUM  SELFINJURY=MEDIUM-HIGH
# 50  FAT=LOW-MEDIUM   OVERWT=LOW-MEDIUM  SELFINJURY=MEDIUM-HIGH
# 51  FAT=LOW-MEDIUM   OVERWT=LOW-MEDIUM  SELFINJURY=MEDIUM-HIGH
# 52  FAT=LOW-MEDIUM   OVERWT=LOW-MEDIUM  SELFINJURY=MEDIUM-HIGH
# 53  FAT=LOW-MEDIUM   OVERWT=LOW-MEDIUM  SELFINJURY=MEDIUM-HIGH
# 54  FAT=LOW-MEDIUM   OVERWT=LOW-MEDIUM  SELFINJURY=MEDIUM-HIGH
# 55      FAT=MEDIUM       OVERWT=MEDIUM       SELFINJURY=MEDIUM
# 56      FAT=MEDIUM       OVERWT=MEDIUM       SELFINJURY=MEDIUM
# 57      FAT=MEDIUM       OVERWT=MEDIUM       SELFINJURY=MEDIUM
# 58      FAT=MEDIUM       OVERWT=MEDIUM       SELFINJURY=MEDIUM
# 59      FAT=MEDIUM       OVERWT=MEDIUM       SELFINJURY=MEDIUM
# 60      FAT=MEDIUM       OVERWT=MEDIUM       SELFINJURY=MEDIUM
# 61      FAT=MEDIUM       OVERWT=MEDIUM       SELFINJURY=MEDIUM
#
#                 CALORIES              TOTALHOSPBED             HEARTDISEAS  \
# 44   CALORIES=LOW-MEDIUM   TOTALHOSPBED=LOW-MEDIUM      HEARTDISEAS=MEDIUM
# 45   CALORIES=LOW-MEDIUM   TOTALHOSPBED=LOW-MEDIUM      HEARTDISEAS=MEDIUM
# 46   CALORIES=LOW-MEDIUM   TOTALHOSPBED=LOW-MEDIUM      HEARTDISEAS=MEDIUM
# 47       CALORIES=MEDIUM  TOTALHOSPBED=MEDIUM-HIGH         HEARTDISEAS=LOW
# 48       CALORIES=MEDIUM  TOTALHOSPBED=MEDIUM-HIGH         HEARTDISEAS=LOW
# 49       CALORIES=MEDIUM  TOTALHOSPBED=MEDIUM-HIGH         HEARTDISEAS=LOW
# 50       CALORIES=MEDIUM  TOTALHOSPBED=MEDIUM-HIGH         HEARTDISEAS=LOW
# 51       CALORIES=MEDIUM  TOTALHOSPBED=MEDIUM-HIGH         HEARTDISEAS=LOW
# 52       CALORIES=MEDIUM  TOTALHOSPBED=MEDIUM-HIGH         HEARTDISEAS=LOW
# 53       CALORIES=MEDIUM  TOTALHOSPBED=MEDIUM-HIGH         HEARTDISEAS=LOW
# 54       CALORIES=MEDIUM  TOTALHOSPBED=MEDIUM-HIGH         HEARTDISEAS=LOW
# 55  CALORIES=MEDIUM-HIGH       TOTALHOSPBED=MEDIUM  HEARTDISEAS=LOW-MEDIUM
# 56  CALORIES=MEDIUM-HIGH       TOTALHOSPBED=MEDIUM  HEARTDISEAS=LOW-MEDIUM
# 57  CALORIES=MEDIUM-HIGH       TOTALHOSPBED=MEDIUM  HEARTDISEAS=LOW-MEDIUM
# 58  CALORIES=MEDIUM-HIGH       TOTALHOSPBED=MEDIUM  HEARTDISEAS=LOW-MEDIUM
# 59  CALORIES=MEDIUM-HIGH       TOTALHOSPBED=MEDIUM  HEARTDISEAS=LOW-MEDIUM
# 60  CALORIES=MEDIUM-HIGH       TOTALHOSPBED=MEDIUM  HEARTDISEAS=LOW-MEDIUM
# 61  CALORIES=MEDIUM-HIGH       TOTALHOSPBED=MEDIUM  HEARTDISEAS=LOW-MEDIUM
#
#                 LIFEEXP              ALCOHOL              PROTEIN  \
# 44  LIFEEXP=MEDIUM-HIGH       ALCOHOL=MEDIUM       PROTEIN=MEDIUM
# 45  LIFEEXP=MEDIUM-HIGH       ALCOHOL=MEDIUM       PROTEIN=MEDIUM
# 46  LIFEEXP=MEDIUM-HIGH       ALCOHOL=MEDIUM       PROTEIN=MEDIUM
# 47          LIFEEXP=LOW          ALCOHOL=LOW  PROTEIN=MEDIUM-HIGH
# 48          LIFEEXP=LOW          ALCOHOL=LOW  PROTEIN=MEDIUM-HIGH
# 49          LIFEEXP=LOW          ALCOHOL=LOW  PROTEIN=MEDIUM-HIGH
# 50          LIFEEXP=LOW          ALCOHOL=LOW  PROTEIN=MEDIUM-HIGH
# 51          LIFEEXP=LOW          ALCOHOL=LOW  PROTEIN=MEDIUM-HIGH
# 52          LIFEEXP=LOW          ALCOHOL=LOW  PROTEIN=MEDIUM-HIGH
# 53          LIFEEXP=LOW          ALCOHOL=LOW  PROTEIN=MEDIUM-HIGH
# 54          LIFEEXP=LOW          ALCOHOL=LOW  PROTEIN=MEDIUM-HIGH
# 55   LIFEEXP=LOW-MEDIUM  ALCOHOL=MEDIUM-HIGH          PROTEIN=LOW
# 56   LIFEEXP=LOW-MEDIUM  ALCOHOL=MEDIUM-HIGH          PROTEIN=LOW
# 57   LIFEEXP=LOW-MEDIUM  ALCOHOL=MEDIUM-HIGH          PROTEIN=LOW
# 58   LIFEEXP=LOW-MEDIUM  ALCOHOL=MEDIUM-HIGH          PROTEIN=LOW
# 59   LIFEEXP=LOW-MEDIUM  ALCOHOL=MEDIUM-HIGH          PROTEIN=LOW
# 60   LIFEEXP=LOW-MEDIUM  ALCOHOL=MEDIUM-HIGH          PROTEIN=LOW
# 61   LIFEEXP=LOW-MEDIUM  ALCOHOL=MEDIUM-HIGH          PROTEIN=LOW
#
#                 cluster
# 44  cluster=MEDIUM-HIGH
# 45  cluster=MEDIUM-HIGH
# 46  cluster=MEDIUM-HIGH
# 47   cluster=LOW-MEDIUM
# 48   cluster=LOW-MEDIUM
# 49   cluster=LOW-MEDIUM
# 50   cluster=LOW-MEDIUM
# 51   cluster=LOW-MEDIUM
# 52   cluster=LOW-MEDIUM
# 53   cluster=LOW-MEDIUM
# 54   cluster=LOW-MEDIUM
# 55          cluster=LOW
# 56          cluster=LOW
# 57          cluster=LOW
# 58          cluster=LOW
# 59          cluster=LOW
# 60          cluster=LOW
# 61          cluster=LOW

# %%
filterByYear
# Out:
#      COUNTRY    YEAR  SEX  circulatory_diseases  youth_unemployment_rate  \
# 0    Austria  1991.0  ALL               3051.58                     3.72
# 1    Austria  1992.0  ALL               3002.43                     4.13
# 2    Austria  1995.0  ALL               2844.85                     5.91
# 3    Austria  1999.0  ALL               2646.71                     5.93
# 4    Austria  2006.0  ALL               1834.76                     9.75
# ..       ...     ...  ...                   ...                      ...
# 250   Sweden  2010.0  ALL               1439.34                    24.64
# 251   Sweden  2011.0  ALL               1381.82                    22.65
# 252   Sweden  2012.0  ALL               1373.36                    23.49
# 253   Sweden  2013.0  ALL               1304.10                    23.33
# 254   Sweden  2014.0  ALL               1251.65                    22.62
#
#      gross_national_income  unemployment_rate  regular_daily_smokers  \
# 0                  21810.0               3.46                   27.5
# 1                  24520.0               3.61                   35.0
# 2                  28190.0               3.66                   24.0
# 3                  27080.0               3.72                   36.3
# 4                  41500.0               5.30                   23.2
# ..                     ...                ...                    ...
# 250                54630.0               8.60                   13.6
# 251                56700.0               7.80                   13.1
# 252                59090.0               8.00                   12.8
# 253                61800.0               8.00                   10.7
# 254                61870.0               7.90                   11.9
#
#      average_fruit_vegtable_ppd  fat_available_ppd  adult_overweight  \
# 0                        209.10             159.23             40.09
# 1                        212.51             161.42             40.40
# 2                        200.16             152.79             41.33
# 3                        205.56             157.23             42.58
# 4                        238.95             162.30             44.27
# ..                          ...                ...               ...
# 250                      150.66             129.79             49.31
# 251                      152.10             132.29             49.44
# 252                      154.73             134.35             49.56
# 253                      153.04             130.49             49.65
# 254                      154.64             135.03             49.75
#
#      self_injury  average_number_of_calories_available_per_person_per_day  \
# 0           1.25                                             3556.0
# 1           1.44                                             3546.0
# 2           1.04                                             3510.0
# 3           0.83                                             3673.0
# 4           0.79                                             3719.0
# ..           ...                                                ...
# 250         0.98                                             3149.0
# 251         0.75                                             3163.0
# 252         0.67                                             3172.0
# 253         0.81                                             3186.0
# 254         0.83                                             3198.0
#
#      total_hospital_beds  Ischaemic_heart_diseas  life_expectancy  \
# 0                70143.0                   38.53            75.95
# 1                69268.0                   37.38            76.13
# 2                67853.0                   35.48            76.97
# 3                64594.0                   30.69            78.13
# 4                63354.0                   18.06            80.19
# ..                   ...                     ...              ...
# 250              25566.0                   14.54            81.76
# 251              25566.0                   13.84            81.99
# 252              24927.0                   12.56            81.90
# 253              24905.0                   12.69            82.11
# 254              24603.0                   11.97            82.44
#
#      alcahol_consumption_liter_per_capita  protein_ppd  cluster
# 0                                   14.10       103.15        2
# 1                                   13.60       103.95        2
# 2                                   13.40       100.54        2
# 3                                   12.80       105.49        1
# 4                                   12.58       101.46        2
# ..                                    ...          ...      ...
# 250                                  7.38       108.49        1
# 251                                  7.31       107.76        1
# 252                                  7.23       105.86        1
# 253                                  7.32       108.84        1
# 254                                  7.20       108.08        1
#
# [255 rows x 19 columns]

# %%
import matplotlib.patches as mpatches
import numpy as np

# Map cluster index -> text label and color (choose colors you like)
cluster_label_map = clusterToLabel()#{0: "Low", 2: "Medium", 1: "High"}
cluster_color_map = {0: "blue", 2: "orange", 1: "green", 3:"red", 4:"gray"}

# Add a color column for plotting
filterByYear["cluster_color"] = filterByYear["cluster"].map(cluster_color_map)

fig, ax = plt.subplots()
ax.set_title("Total hospital beds for different years and countries")

# plot points (y is constant just to show along a horizontal line)
y_line = np.ones(len(filterByYear))
scat = ax.scatter(filterByYear[series_name], y_line, c=filterByYear["cluster_color"], edgecolor='k', alpha=0.8)

# plot cluster centers (use the same color mapping: cluster center order corresponds to cluster indices)
center_x = y_pred.cluster_centers_[:, 1]  # your centers
center_colors = [cluster_color_map[i] for i in range(len(center_x))]
ax.scatter(center_x, np.ones(len(center_x)), marker='+', c="red", label="Center of Cluster")

# build manual legend for Low/Medium/High
handles = [mpatches.Patch(color=cluster_color_map[i], label=cluster_label_map[i]) for i in sorted(cluster_label_map)]
ax.legend(handles=handles + [plt.Line2D([0],[0], marker='+', color='red', label='Center of Cluster', linestyle='')],
          title="Labels",
          loc='upper right')

ax.set_xlabel("Number of beds")
ax.get_yaxis().set_ticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[115], line 24
#      16 scat = ax.scatter(filterByYear[series_name], y_line, c=filterByYear["cluster"], edgecolor='k', alpha=0.8)
#      18 # plot cluster centers (use the same color mapping: cluster center order corresponds to cluster indices)
#      19 # center_x = y_pred.cluster_centers_[:, 1]  # your centers
#      20 # center_colors = [i for i in range(len(center_x))]
#      21 # ax.scatter(center_x, np.ones(len(center_x)), marker='+', c="red", label="Center of Cluster")
#      22
#      23 # build manual legend for Low/Medium/High
# ---> 24 handles = [mpatches.Patch(color=[1,2,3,4,5], label=cluster_label_map[i]) for i in sorted(cluster_label_map)]
#      25 ax.legend(handles=handles + [plt.Line2D([0],[0], marker='+', color='red', label='Center of Cluster', linestyle='')],
#      26           title="Labels",
#      27           loc='upper right')
#      29 ax.set_xlabel("Number of beds")
#
# Cell In[115], line 24, in <listcomp>(.0)
#      16 scat = ax.scatter(filterByYear[series_name], y_line, c=filterByYear["cluster"], edgecolor='k', alpha=0.8)
#      18 # plot cluster centers (use the same color mapping: cluster center order corresponds to cluster indices)
#      19 # center_x = y_pred.cluster_centers_[:, 1]  # your centers
#      20 # center_colors = [i for i in range(len(center_x))]
#      21 # ax.scatter(center_x, np.ones(len(center_x)), marker='+', c="red", label="Center of Cluster")
#      22
#      23 # build manual legend for Low/Medium/High
# ---> 24 handles = [mpatches.Patch(color=[1,2,3,4,5], label=cluster_label_map[i]) for i in sorted(cluster_label_map)]
#      25 ax.legend(handles=handles + [plt.Line2D([0],[0], marker='+', color='red', label='Center of Cluster', linestyle='')],
#      26           title="Labels",
#      27           loc='upper right')
#      29 ax.set_xlabel("Number of beds")
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/patches.py:82, in Patch.__init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      78     if edgecolor is not None or facecolor is not None:
#      79         _api.warn_external(
#      80             "Setting the 'color' property will override "
#      81             "the edgecolor or facecolor properties.")
# ---> 82     self.set_color(color)
#      83 else:
#      84     self.set_edgecolor(edgecolor)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/patches.py:374, in Patch.set_color(self, c)
#     361 def set_color(self, c):
#     362     """
#     363     Set both the edgecolor and the facecolor.
#     364
#    (...)
#     372         For setting the edge or face color individually.
#     373     """
# --> 374     self.set_facecolor(c)
#     375     self.set_edgecolor(c)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/patches.py:359, in Patch.set_facecolor(self, color)
#     351 """
#     352 Set the patch face color.
#     353
#    (...)
#     356 color : color or None
#     357 """
#     358 self._original_facecolor = color
# --> 359 self._set_facecolor(color)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/patches.py:347, in Patch._set_facecolor(self, color)
#     345     color = mpl.rcParams['patch.facecolor']
#     346 alpha = self._alpha if self._fill else 0
# --> 347 self._facecolor = colors.to_rgba(color, alpha)
#     348 self.stale = True
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/colors.py:299, in to_rgba(c, alpha)
#     297     rgba = None
#     298 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 299     rgba = _to_rgba_no_colorcycle(c, alpha)
#     300     try:
#     301         _colors_full_map.cache[c, alpha] = rgba
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/colors.py:383, in _to_rgba_no_colorcycle(c, alpha)
#     381     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     382 if len(c) not in [3, 4]:
# --> 383     raise ValueError("RGBA sequence should have length 3 or 4")
#     384 if not all(isinstance(x, Number) for x in c):
#     385     # Checks that don't work: `map(float, ...)`, `np.array(..., float)` and
#     386     # `np.array(...).astype(float)` would all convert "0.5" to 0.5.
#     387     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#
# ValueError: RGBA sequence should have length 3 or 4
