# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("European_citiznes_rsvp_eu_clean.csv")
df.head()
# Out:
#    COUNTRY    YEAR  SEX  circulatory_diseases  youth_unemployment_rate  \
# 0  Austria  1991.0  ALL               3051.58                     3.72
# 1  Austria  1992.0  ALL               3002.43                     4.13
# 2  Austria  1995.0  ALL               2844.85                     5.91
# 3  Austria  1999.0  ALL               2646.71                     5.93
# 4  Austria  2006.0  ALL               1834.76                     9.75
#
#    gross_national_income  unemployment_rate  regular_daily_smokers  \
# 0                21810.0               3.46                   27.5
# 1                24520.0               3.61                   35.0
# 2                28190.0               3.66                   24.0
# 3                27080.0               3.72                   36.3
# 4                41500.0               5.30                   23.2
#
#    average_fruit_vegtable_ppd  fat_available_ppd  adult_overweight  \
# 0                      209.10             159.23             40.09
# 1                      212.51             161.42             40.40
# 2                      200.16             152.79             41.33
# 3                      205.56             157.23             42.58
# 4                      238.95             162.30             44.27
#
#    self_injury  average_number_of_calories_available_per_person_per_day  \
# 0         1.25                                             3556.0
# 1         1.44                                             3546.0
# 2         1.04                                             3510.0
# 3         0.83                                             3673.0
# 4         0.79                                             3719.0
#
#    total_hospital_beds  Ischaemic_heart_diseas  life_expectancy  \
# 0              70143.0                   38.53            75.95
# 1              69268.0                   37.38            76.13
# 2              67853.0                   35.48            76.97
# 3              64594.0                   30.69            78.13
# 4              63354.0                   18.06            80.19
#
#    alcahol_consumption_liter_per_capita  protein_ppd
# 0                                 14.10       103.15
# 1                                 13.60       103.95
# 2                                 13.40       100.54
# 3                                 12.80       105.49
# 4                                 12.58       101.46

# %%
# filterByYear = df[df["YEAR"]==2000]
filterByYear = df
filterByYear[["COUNTRY","YEAR","life_expectancy"]].head()
# Out:
#    COUNTRY    YEAR  life_expectancy
# 0  Austria  1991.0            75.95
# 1  Austria  1992.0            76.13
# 2  Austria  1995.0            76.97
# 3  Austria  1999.0            78.13
# 4  Austria  2006.0            80.19

# %%
import numpy as np

forExport = filterByYear.copy()
labels = ['LOW','MEDIUM', 'HIGH']

def clusterToLabel(centers):
    labelMap = []
    # for c in arr:
    # centers = np.array([2.5, -1.2, 0.7])  # cluster 0,1,2
    sorted_labels = np.argsort(centers)       # array([1,2,0]) low->high
    rank_map = {int(lbl): rank for rank, lbl in enumerate(sorted_labels, start=0)}  # {1:1,2:2,0:3}
    # labels: array of shape (n_samples,) with cluster ids
    labels = np.array([0,0,1,2,1,2])
    # print(rank_map)
    return rank_map

clusterToLabel([0.5, 3, 2])
# Out:
# {0: 0, 2: 1, 1: 2}

# %%
health = [
    "circulatory_diseases",
    "adult_overweight",
    "Ischaemic_heart_diseas",
    "life_expectancy",
]
social = [
    "regular_daily_smokers",
    "average_fruit_vegtable_ppd",
    "fat_available_ppd",
    "self_injury",
    "average_number_of_calories_available_per_person_per_day",
    "alcahol_consumption_liter_per_capita",
    "protein_ppd"
    "youth_unemployment_rate",
    "unemployment_rate",
    "gross_national_income",
],
econ = [
    "total_hospital_beds",
    "total_hospital_beds",
]

# %%
from sklearn.cluster import KMeans

filterByYear3 = filterByYear.copy()

y_pred = KMeans(n_clusters=3).fit(filterByYear3[econ])
y_pred.predict(filterByYear3[econ])
y_pred.cluster_centers_
filterByYear3["cluster"] = y_pred.labels_
filterByYear3[["COUNTRY","YEAR","cluster"] + econ].head()
# Out:
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#    COUNTRY    YEAR  cluster  total_hospital_beds  total_hospital_beds
# 0  Austria  1991.0        0              70143.0              70143.0
# 1  Austria  1992.0        0              69268.0              69268.0
# 2  Austria  1995.0        0              67853.0              67853.0
# 3  Austria  1999.0        0              64594.0              64594.0
# 4  Austria  2006.0        0              63354.0              63354.0

# %%
relab = clusterToLabel(y_pred.cluster_centers_[:,1])

for i in range(len(filterByYear3['cluster'])):
        filterByYear3['cluster'][i] = labels[relab.get(filterByYear3['cluster'][i])]

filterByYear3.loc[filterByYear3['cluster'] == 'LOW']
# Out:
# /tmp/ipykernel_1263/2194719547.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filterByYear3['cluster'][i] = labels[relab.get(filterByYear3['cluster'][i])]
#      COUNTRY    YEAR  SEX  circulatory_diseases  youth_unemployment_rate  \
# 0    Austria  1991.0  ALL               3051.58                     3.72
# 1    Austria  1992.0  ALL               3002.43                     4.13
# 2    Austria  1995.0  ALL               2844.85                     5.91
# 3    Austria  1999.0  ALL               2646.71                     5.93
# 4    Austria  2006.0  ALL               1834.76                     9.75
# ..       ...     ...  ...                   ...                      ...
# 250   Sweden  2010.0  ALL               1439.34                    24.64
# 251   Sweden  2011.0  ALL               1381.82                    22.65
# 252   Sweden  2012.0  ALL               1373.36                    23.49
# 253   Sweden  2013.0  ALL               1304.10                    23.33
# 254   Sweden  2014.0  ALL               1251.65                    22.62
#
#      gross_national_income  unemployment_rate  regular_daily_smokers  \
# 0                  21810.0               3.46                   27.5
# 1                  24520.0               3.61                   35.0
# 2                  28190.0               3.66                   24.0
# 3                  27080.0               3.72                   36.3
# 4                  41500.0               5.30                   23.2
# ..                     ...                ...                    ...
# 250                54630.0               8.60                   13.6
# 251                56700.0               7.80                   13.1
# 252                59090.0               8.00                   12.8
# 253                61800.0               8.00                   10.7
# 254                61870.0               7.90                   11.9
#
#      average_fruit_vegtable_ppd  fat_available_ppd  adult_overweight  \
# 0                        209.10             159.23             40.09
# 1                        212.51             161.42             40.40
# 2                        200.16             152.79             41.33
# 3                        205.56             157.23             42.58
# 4                        238.95             162.30             44.27
# ..                          ...                ...               ...
# 250                      150.66             129.79             49.31
# 251                      152.10             132.29             49.44
# 252                      154.73             134.35             49.56
# 253                      153.04             130.49             49.65
# 254                      154.64             135.03             49.75
#
#      self_injury  average_number_of_calories_available_per_person_per_day  \
# 0           1.25                                             3556.0
# 1           1.44                                             3546.0
# 2           1.04                                             3510.0
# 3           0.83                                             3673.0
# 4           0.79                                             3719.0
# ..           ...                                                ...
# 250         0.98                                             3149.0
# 251         0.75                                             3163.0
# 252         0.67                                             3172.0
# 253         0.81                                             3186.0
# 254         0.83                                             3198.0
#
#      total_hospital_beds  Ischaemic_heart_diseas  life_expectancy  \
# 0                70143.0                   38.53            75.95
# 1                69268.0                   37.38            76.13
# 2                67853.0                   35.48            76.97
# 3                64594.0                   30.69            78.13
# 4                63354.0                   18.06            80.19
# ..                   ...                     ...              ...
# 250              25566.0                   14.54            81.76
# 251              25566.0                   13.84            81.99
# 252              24927.0                   12.56            81.90
# 253              24905.0                   12.69            82.11
# 254              24603.0                   11.97            82.44
#
#      alcahol_consumption_liter_per_capita  protein_ppd cluster
# 0                                   14.10       103.15     LOW
# 1                                   13.60       103.95     LOW
# 2                                   13.40       100.54     LOW
# 3                                   12.80       105.49     LOW
# 4                                   12.58       101.46     LOW
# ..                                    ...          ...     ...
# 250                                  7.38       108.49     LOW
# 251                                  7.31       107.76     LOW
# 252                                  7.23       105.86     LOW
# 253                                  7.32       108.84     LOW
# 254                                  7.20       108.08     LOW
#
# [213 rows x 19 columns]

# %%
from sklearn.cluster import KMeans
import numpy as np

X = np.array([[1, 2], [1, 4], [1, 0],
              [10, 2], [10, 4], [10, 0]])
kmeans = KMeans(n_clusters=3, random_state=0, n_init="auto").fit(filterByYear[["life_expectancy","life_expectancy"]])
kmeans.labels_
#kmeans.predict([[0, 0], [12, 3]])
kmeans.cluster_centers_
# Out:
# array([[72.42227273, 72.42227273],
#        [77.33650943, 77.33650943],
#        [80.7592381 , 80.7592381 ]])

# %%
from sklearn.cluster import KMeans

y_pred = KMeans(n_clusters=3, random_state=0, n_init="auto").fit(filterByYear[["YEAR","life_expectancy"]])
y_pred.predict(filterByYear[["YEAR","life_expectancy"]])
filterByYear["cluster"] = y_pred.labels_
filterByYear[["COUNTRY","YEAR","life_expectancy","cluster"]].head()

y_pred.cluster_centers_[:,1]
# y_pred.labels_
# Out:
# array([76.20710145, 77.36438776, 79.81784091])

# %%
fig, ax = plt.subplots()
ax.scatter(filterByYear["life_expectancy"], filterByYear["life_expectancy"], c=filterByYear["cluster"])
ax.scatter(y_pred.cluster_centers_[:,1], y_pred.cluster_centers_[:,1], c='red', marker='+')
ax.grid(True)

plt.show()

# %%
for series_name, series in df.items():
    if series_name == "COUNTRY" or series_name == "SEX" or series_name == "YEAR":
        continue
    print(series_name)
    y_pred = KMeans(n_clusters=3).fit(filterByYear[[series_name,series_name]])
    y_pred.predict(filterByYear[[series_name,series_name]])
    y_pred.cluster_centers_
    filterByYear["cluster"] = y_pred.labels_
    filterByYear[["COUNTRY","YEAR",series_name,"cluster"]].head()

    fig, ax = plt.subplots()
    ax.scatter(filterByYear[series_name], filterByYear[series_name], c=filterByYear["cluster"])
    ax.scatter(y_pred.cluster_centers_[:,1], y_pred.cluster_centers_[:,1], c='red', marker='+')
    ax.grid(True)
    ax.set_title(series_name)

    plt.show()

    relab = clusterToLabel(y_pred.cluster_centers_[:,1])

    for i in range(len(filterByYear[series_name])):
        forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]

forExport
# Out:
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# circulatory_diseases
# youth_unemployment_rate
# /tmp/ipykernel_1263/1809275560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /tmp/ipykernel_1263/1809275560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# gross_national_income
# unemployment_rate
# /tmp/ipykernel_1263/1809275560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /tmp/ipykernel_1263/1809275560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# regular_daily_smokers
# average_fruit_vegtable_ppd
# /tmp/ipykernel_1263/1809275560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /tmp/ipykernel_1263/1809275560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# fat_available_ppd
# /tmp/ipykernel_1263/1809275560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# adult_overweight
# /tmp/ipykernel_1263/1809275560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# self_injury
# /tmp/ipykernel_1263/1809275560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# average_number_of_calories_available_per_person_per_day
# total_hospital_beds
# /tmp/ipykernel_1263/1809275560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /tmp/ipykernel_1263/1809275560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Ischaemic_heart_diseas
# life_expectancy
# /tmp/ipykernel_1263/1809275560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /tmp/ipykernel_1263/1809275560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# alcahol_consumption_liter_per_capita
# /tmp/ipykernel_1263/1809275560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# protein_ppd
# /tmp/ipykernel_1263/1809275560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]
# /home/viereck/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# cluster
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cluster'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[191], line 22
#      19     relab = clusterToLabel(y_pred.cluster_centers_[:,1])
#      21     for i in range(len(filterByYear[series_name])):
# ---> 22         forExport[series_name][i] = labels[relab.get(filterByYear['cluster'][i])]
#      24 forExport
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'cluster'

# %%
rename_map = {
    "life_expectancy": "LIFEEXP",
    "average_number_of_calories_available_per_person_per_day": "CALORIES",
    "unemployment_rate": "UNEMP",
    "regular_daily_smokers": "SMOKING",
    "adult_overweight": "OVERWT",
    "alcahol_consumption_liter_per_capita": "ALCOHOL",
    "fat_available_ppd": "FAT",
    "protein_ppd": "PROTEIN",
    "average_fruit_vegtable_ppd": "FRUITVEG",
    "annual_income": "ANNUALINCOME",  
    "youth_unemployment_rate": "YOUTH_UNEMP_RATE",  
    "Ischaemic_heart_diseas": "HEARTDISEAS",  
    "circulatory_diseases": "CIRCULATORYDISEAS",  
    "self_injury": "SELFINJURY",  
    "total_hospital_beds": "TOTALHOSPBED",  
    "gross_national_income": "GROSS_NATIONAL_INCOME"
}

# item_cols = [c+"_bin" for c in cols_to_bin]
# print(item_cols)

forExport = forExport.rename(columns=rename_map)

# df = pd.DataFrame({"z":["a","a"], "zz":["b","c"]}, index=[1,2])

# Option 1 — transform all columns to "col=val" strings
# df_transformed = df.apply(lambda col: col.index.map(lambda i, c=col.name: f"{c}={col.loc[i]}"))
# but simpler:
forExport2 = forExport.apply(lambda col: col.map(lambda v, name=col.name: f"{name}={v}")).copy()

print(forExport2)

# 1 transaction = one (COUNTRY, YEAR)
tx_df = (forExport2.sort_values(["COUNTRY","YEAR"])
           .drop_duplicates(subset=["COUNTRY","YEAR"]))


transactions = forExport2#tx_df.apply(row_to_items, axis=1).tolist()
transactions = transactions.drop(columns=["COUNTRY","YEAR","SEX","cluster"])
num_records = len(transactions)
# print(transactions)
print("Transactions:", num_records)

# pd.DataFrame(transactions).to_csv("rules_stat_cluster_new.csv", index=False)
# Out:
#              COUNTRY         YEAR      SEX         CIRCULATORYDISEAS  \
# 0    COUNTRY=Austria  YEAR=1991.0  SEX=ALL  CIRCULATORYDISEAS=MEDIUM
# 1    COUNTRY=Austria  YEAR=1992.0  SEX=ALL  CIRCULATORYDISEAS=MEDIUM
# 2    COUNTRY=Austria  YEAR=1995.0  SEX=ALL  CIRCULATORYDISEAS=MEDIUM
# 3    COUNTRY=Austria  YEAR=1999.0  SEX=ALL  CIRCULATORYDISEAS=MEDIUM
# 4    COUNTRY=Austria  YEAR=2006.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# ..               ...          ...      ...                       ...
# 250   COUNTRY=Sweden  YEAR=2010.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 251   COUNTRY=Sweden  YEAR=2011.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 252   COUNTRY=Sweden  YEAR=2012.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 253   COUNTRY=Sweden  YEAR=2013.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 254   COUNTRY=Sweden  YEAR=2014.0  SEX=ALL     CIRCULATORYDISEAS=LOW
#
#             YOUTH_UNEMP_RATE         GROSS_NATIONAL_INCOME      UNEMP  \
# 0       YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=MEDIUM  UNEMP=LOW
# 1       YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=MEDIUM  UNEMP=LOW
# 2       YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=MEDIUM  UNEMP=LOW
# 3       YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=MEDIUM  UNEMP=LOW
# 4       YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=MEDIUM  UNEMP=LOW
# ..                       ...                           ...        ...
# 250  YOUTH_UNEMP_RATE=MEDIUM    GROSS_NATIONAL_INCOME=HIGH  UNEMP=LOW
# 251  YOUTH_UNEMP_RATE=MEDIUM    GROSS_NATIONAL_INCOME=HIGH  UNEMP=LOW
# 252  YOUTH_UNEMP_RATE=MEDIUM    GROSS_NATIONAL_INCOME=HIGH  UNEMP=LOW
# 253  YOUTH_UNEMP_RATE=MEDIUM    GROSS_NATIONAL_INCOME=HIGH  UNEMP=LOW
# 254  YOUTH_UNEMP_RATE=MEDIUM    GROSS_NATIONAL_INCOME=HIGH  UNEMP=LOW
#
#             SMOKING         FRUITVEG         FAT         OVERWT  \
# 0    SMOKING=MEDIUM  FRUITVEG=MEDIUM    FAT=HIGH     OVERWT=LOW
# 1      SMOKING=HIGH  FRUITVEG=MEDIUM    FAT=HIGH     OVERWT=LOW
# 2    SMOKING=MEDIUM  FRUITVEG=MEDIUM    FAT=HIGH     OVERWT=LOW
# 3      SMOKING=HIGH  FRUITVEG=MEDIUM    FAT=HIGH     OVERWT=LOW
# 4    SMOKING=MEDIUM  FRUITVEG=MEDIUM    FAT=HIGH     OVERWT=LOW
# ..              ...              ...         ...            ...
# 250     SMOKING=LOW     FRUITVEG=LOW  FAT=MEDIUM  OVERWT=MEDIUM
# 251     SMOKING=LOW     FRUITVEG=LOW  FAT=MEDIUM  OVERWT=MEDIUM
# 252     SMOKING=LOW     FRUITVEG=LOW  FAT=MEDIUM  OVERWT=MEDIUM
# 253     SMOKING=LOW     FRUITVEG=LOW  FAT=MEDIUM  OVERWT=MEDIUM
# 254     SMOKING=LOW     FRUITVEG=LOW  FAT=MEDIUM  OVERWT=MEDIUM
#
#          SELFINJURY         CALORIES      TOTALHOSPBED         HEARTDISEAS  \
# 0    SELFINJURY=LOW    CALORIES=HIGH  TOTALHOSPBED=LOW  HEARTDISEAS=MEDIUM
# 1    SELFINJURY=LOW    CALORIES=HIGH  TOTALHOSPBED=LOW  HEARTDISEAS=MEDIUM
# 2    SELFINJURY=LOW    CALORIES=HIGH  TOTALHOSPBED=LOW  HEARTDISEAS=MEDIUM
# 3    SELFINJURY=LOW    CALORIES=HIGH  TOTALHOSPBED=LOW  HEARTDISEAS=MEDIUM
# 4    SELFINJURY=LOW    CALORIES=HIGH  TOTALHOSPBED=LOW     HEARTDISEAS=LOW
# ..              ...              ...               ...                 ...
# 250  SELFINJURY=LOW  CALORIES=MEDIUM  TOTALHOSPBED=LOW     HEARTDISEAS=LOW
# 251  SELFINJURY=LOW  CALORIES=MEDIUM  TOTALHOSPBED=LOW     HEARTDISEAS=LOW
# 252  SELFINJURY=LOW  CALORIES=MEDIUM  TOTALHOSPBED=LOW     HEARTDISEAS=LOW
# 253  SELFINJURY=LOW  CALORIES=MEDIUM  TOTALHOSPBED=LOW     HEARTDISEAS=LOW
# 254  SELFINJURY=LOW  CALORIES=MEDIUM  TOTALHOSPBED=LOW     HEARTDISEAS=LOW
#
#             LIFEEXP       ALCOHOL         PROTEIN       cluster
# 0    LIFEEXP=MEDIUM  ALCOHOL=HIGH  PROTEIN=MEDIUM  cluster=HIGH
# 1    LIFEEXP=MEDIUM  ALCOHOL=HIGH  PROTEIN=MEDIUM  cluster=HIGH
# 2    LIFEEXP=MEDIUM  ALCOHOL=HIGH  PROTEIN=MEDIUM  cluster=HIGH
# 3    LIFEEXP=MEDIUM  ALCOHOL=HIGH    PROTEIN=HIGH   cluster=LOW
# 4      LIFEEXP=HIGH  ALCOHOL=HIGH  PROTEIN=MEDIUM  cluster=HIGH
# ..              ...           ...             ...           ...
# 250    LIFEEXP=HIGH   ALCOHOL=LOW    PROTEIN=HIGH   cluster=LOW
# 251    LIFEEXP=HIGH   ALCOHOL=LOW    PROTEIN=HIGH   cluster=LOW
# 252    LIFEEXP=HIGH   ALCOHOL=LOW    PROTEIN=HIGH   cluster=LOW
# 253    LIFEEXP=HIGH   ALCOHOL=LOW    PROTEIN=HIGH   cluster=LOW
# 254    LIFEEXP=HIGH   ALCOHOL=LOW    PROTEIN=HIGH   cluster=LOW
#
# [255 rows x 19 columns]
# Transactions: 255

# %%
tt = forExport2
tt.loc[tt['COUNTRY'] == "COUNTRY=Denmark"]
# Out:
#             COUNTRY         YEAR      SEX         CIRCULATORYDISEAS  \
# 44  COUNTRY=Denmark  YEAR=1997.0  SEX=ALL  CIRCULATORYDISEAS=MEDIUM
# 45  COUNTRY=Denmark  YEAR=1998.0  SEX=ALL  CIRCULATORYDISEAS=MEDIUM
# 46  COUNTRY=Denmark  YEAR=1999.0  SEX=ALL  CIRCULATORYDISEAS=MEDIUM
# 47  COUNTRY=Denmark  YEAR=2000.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 48  COUNTRY=Denmark  YEAR=2001.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 49  COUNTRY=Denmark  YEAR=2002.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 50  COUNTRY=Denmark  YEAR=2003.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 51  COUNTRY=Denmark  YEAR=2004.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 52  COUNTRY=Denmark  YEAR=2005.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 53  COUNTRY=Denmark  YEAR=2006.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 54  COUNTRY=Denmark  YEAR=2007.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 55  COUNTRY=Denmark  YEAR=2008.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 56  COUNTRY=Denmark  YEAR=2009.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 57  COUNTRY=Denmark  YEAR=2010.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 58  COUNTRY=Denmark  YEAR=2011.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 59  COUNTRY=Denmark  YEAR=2013.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 60  COUNTRY=Denmark  YEAR=2014.0  SEX=ALL     CIRCULATORYDISEAS=LOW
# 61  COUNTRY=Denmark  YEAR=2015.0  SEX=ALL     CIRCULATORYDISEAS=LOW
#
#            YOUTH_UNEMP_RATE         GROSS_NATIONAL_INCOME      UNEMP  \
# 44     YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=MEDIUM  UNEMP=LOW
# 45     YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=MEDIUM  UNEMP=LOW
# 46     YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=MEDIUM  UNEMP=LOW
# 47     YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=MEDIUM  UNEMP=LOW
# 48     YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=MEDIUM  UNEMP=LOW
# 49     YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=MEDIUM  UNEMP=LOW
# 50     YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=MEDIUM  UNEMP=LOW
# 51     YOUTH_UNEMP_RATE=LOW  GROSS_NATIONAL_INCOME=MEDIUM  UNEMP=LOW
# 52     YOUTH_UNEMP_RATE=LOW    GROSS_NATIONAL_INCOME=HIGH  UNEMP=LOW
# 53     YOUTH_UNEMP_RATE=LOW    GROSS_NATIONAL_INCOME=HIGH  UNEMP=LOW
# 54     YOUTH_UNEMP_RATE=LOW    GROSS_NATIONAL_INCOME=HIGH  UNEMP=LOW
# 55     YOUTH_UNEMP_RATE=LOW    GROSS_NATIONAL_INCOME=HIGH  UNEMP=LOW
# 56     YOUTH_UNEMP_RATE=LOW    GROSS_NATIONAL_INCOME=HIGH  UNEMP=LOW
# 57     YOUTH_UNEMP_RATE=LOW    GROSS_NATIONAL_INCOME=HIGH  UNEMP=LOW
# 58  YOUTH_UNEMP_RATE=MEDIUM    GROSS_NATIONAL_INCOME=HIGH  UNEMP=LOW
# 59     YOUTH_UNEMP_RATE=LOW    GROSS_NATIONAL_INCOME=HIGH  UNEMP=LOW
# 60     YOUTH_UNEMP_RATE=LOW    GROSS_NATIONAL_INCOME=HIGH  UNEMP=LOW
# 61     YOUTH_UNEMP_RATE=LOW    GROSS_NATIONAL_INCOME=HIGH  UNEMP=LOW
#
#            SMOKING         FRUITVEG         FAT      OVERWT      SELFINJURY  \
# 44    SMOKING=HIGH  FRUITVEG=MEDIUM  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 45    SMOKING=HIGH     FRUITVEG=LOW  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 46    SMOKING=HIGH  FRUITVEG=MEDIUM  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 47    SMOKING=HIGH  FRUITVEG=MEDIUM  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 48    SMOKING=HIGH  FRUITVEG=MEDIUM  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 49  SMOKING=MEDIUM    FRUITVEG=HIGH  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 50  SMOKING=MEDIUM  FRUITVEG=MEDIUM  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 51  SMOKING=MEDIUM  FRUITVEG=MEDIUM  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 52  SMOKING=MEDIUM  FRUITVEG=MEDIUM  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 53  SMOKING=MEDIUM  FRUITVEG=MEDIUM  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 54  SMOKING=MEDIUM  FRUITVEG=MEDIUM  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 55  SMOKING=MEDIUM  FRUITVEG=MEDIUM  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 56     SMOKING=LOW  FRUITVEG=MEDIUM  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 57     SMOKING=LOW  FRUITVEG=MEDIUM  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 58     SMOKING=LOW  FRUITVEG=MEDIUM  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 59     SMOKING=LOW     FRUITVEG=LOW  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 60     SMOKING=LOW     FRUITVEG=LOW  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
# 61     SMOKING=LOW     FRUITVEG=LOW  FAT=MEDIUM  OVERWT=LOW  SELFINJURY=LOW
#
#            CALORIES      TOTALHOSPBED      HEARTDISEAS         LIFEEXP  \
# 44  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW  LIFEEXP=MEDIUM
# 45  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW  LIFEEXP=MEDIUM
# 46  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW  LIFEEXP=MEDIUM
# 47  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW  LIFEEXP=MEDIUM
# 48  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW  LIFEEXP=MEDIUM
# 49  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW  LIFEEXP=MEDIUM
# 50  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW  LIFEEXP=MEDIUM
# 51  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW  LIFEEXP=MEDIUM
# 52  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW  LIFEEXP=MEDIUM
# 53  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW  LIFEEXP=MEDIUM
# 54    CALORIES=HIGH  TOTALHOSPBED=LOW  HEARTDISEAS=LOW  LIFEEXP=MEDIUM
# 55  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW  LIFEEXP=MEDIUM
# 56  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW    LIFEEXP=HIGH
# 57  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW    LIFEEXP=HIGH
# 58  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW    LIFEEXP=HIGH
# 59  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW    LIFEEXP=HIGH
# 60  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW    LIFEEXP=HIGH
# 61  CALORIES=MEDIUM  TOTALHOSPBED=LOW  HEARTDISEAS=LOW    LIFEEXP=HIGH
#
#            ALCOHOL         PROTEIN       cluster
# 44    ALCOHOL=HIGH  PROTEIN=MEDIUM  cluster=HIGH
# 45  ALCOHOL=MEDIUM    PROTEIN=HIGH   cluster=LOW
# 46  ALCOHOL=MEDIUM  PROTEIN=MEDIUM  cluster=HIGH
# 47  ALCOHOL=MEDIUM  PROTEIN=MEDIUM  cluster=HIGH
# 48  ALCOHOL=MEDIUM    PROTEIN=HIGH   cluster=LOW
# 49  ALCOHOL=MEDIUM    PROTEIN=HIGH   cluster=LOW
# 50  ALCOHOL=MEDIUM  PROTEIN=MEDIUM  cluster=HIGH
# 51  ALCOHOL=MEDIUM    PROTEIN=HIGH   cluster=LOW
# 52  ALCOHOL=MEDIUM    PROTEIN=HIGH   cluster=LOW
# 53  ALCOHOL=MEDIUM    PROTEIN=HIGH   cluster=LOW
# 54  ALCOHOL=MEDIUM    PROTEIN=HIGH   cluster=LOW
# 55  ALCOHOL=MEDIUM    PROTEIN=HIGH   cluster=LOW
# 56  ALCOHOL=MEDIUM  PROTEIN=MEDIUM  cluster=HIGH
# 57  ALCOHOL=MEDIUM    PROTEIN=HIGH   cluster=LOW
# 58  ALCOHOL=MEDIUM  PROTEIN=MEDIUM  cluster=HIGH
# 59  ALCOHOL=MEDIUM    PROTEIN=HIGH   cluster=LOW
# 60  ALCOHOL=MEDIUM    PROTEIN=HIGH   cluster=LOW
# 61  ALCOHOL=MEDIUM    PROTEIN=HIGH   cluster=LOW

# %%
filterByYear
# Out:
#      COUNTRY    YEAR  SEX  circulatory_diseases  youth_unemployment_rate  \
# 0    Austria  1991.0  ALL               3051.58                     3.72
# 1    Austria  1992.0  ALL               3002.43                     4.13
# 2    Austria  1995.0  ALL               2844.85                     5.91
# 3    Austria  1999.0  ALL               2646.71                     5.93
# 4    Austria  2006.0  ALL               1834.76                     9.75
# ..       ...     ...  ...                   ...                      ...
# 250   Sweden  2010.0  ALL               1439.34                    24.64
# 251   Sweden  2011.0  ALL               1381.82                    22.65
# 252   Sweden  2012.0  ALL               1373.36                    23.49
# 253   Sweden  2013.0  ALL               1304.10                    23.33
# 254   Sweden  2014.0  ALL               1251.65                    22.62
#
#      gross_national_income  unemployment_rate  regular_daily_smokers  \
# 0                  21810.0               3.46                   27.5
# 1                  24520.0               3.61                   35.0
# 2                  28190.0               3.66                   24.0
# 3                  27080.0               3.72                   36.3
# 4                  41500.0               5.30                   23.2
# ..                     ...                ...                    ...
# 250                54630.0               8.60                   13.6
# 251                56700.0               7.80                   13.1
# 252                59090.0               8.00                   12.8
# 253                61800.0               8.00                   10.7
# 254                61870.0               7.90                   11.9
#
#      average_fruit_vegtable_ppd  fat_available_ppd  adult_overweight  \
# 0                        209.10             159.23             40.09
# 1                        212.51             161.42             40.40
# 2                        200.16             152.79             41.33
# 3                        205.56             157.23             42.58
# 4                        238.95             162.30             44.27
# ..                          ...                ...               ...
# 250                      150.66             129.79             49.31
# 251                      152.10             132.29             49.44
# 252                      154.73             134.35             49.56
# 253                      153.04             130.49             49.65
# 254                      154.64             135.03             49.75
#
#      self_injury  average_number_of_calories_available_per_person_per_day  \
# 0           1.25                                             3556.0
# 1           1.44                                             3546.0
# 2           1.04                                             3510.0
# 3           0.83                                             3673.0
# 4           0.79                                             3719.0
# ..           ...                                                ...
# 250         0.98                                             3149.0
# 251         0.75                                             3163.0
# 252         0.67                                             3172.0
# 253         0.81                                             3186.0
# 254         0.83                                             3198.0
#
#      total_hospital_beds  Ischaemic_heart_diseas  life_expectancy  \
# 0                70143.0                   38.53            75.95
# 1                69268.0                   37.38            76.13
# 2                67853.0                   35.48            76.97
# 3                64594.0                   30.69            78.13
# 4                63354.0                   18.06            80.19
# ..                   ...                     ...              ...
# 250              25566.0                   14.54            81.76
# 251              25566.0                   13.84            81.99
# 252              24927.0                   12.56            81.90
# 253              24905.0                   12.69            82.11
# 254              24603.0                   11.97            82.44
#
#      alcahol_consumption_liter_per_capita  protein_ppd  cluster
# 0                                   14.10       103.15        0
# 1                                   13.60       103.95        0
# 2                                   13.40       100.54        0
# 3                                   12.80       105.49        1
# 4                                   12.58       101.46        0
# ..                                    ...          ...      ...
# 250                                  7.38       108.49        1
# 251                                  7.31       107.76        1
# 252                                  7.23       105.86        1
# 253                                  7.32       108.84        1
# 254                                  7.20       108.08        1
#
# [255 rows x 19 columns]

# %%
import matplotlib.patches as mpatches
import numpy as np

# Map cluster index -> text label and color (choose colors you like)
cluster_label_map = {0: "Low", 2: "Medium", 1: "High"}
cluster_color_map = {0: "blue", 1: "orange", 2: "green"}

# Add a color column for plotting
filterByYear["cluster_color"] = filterByYear["cluster"].map(cluster_color_map)

fig, ax = plt.subplots()
ax.set_title("Total hospital beds for different years and countries")

# plot points (y is constant just to show along a horizontal line)
y_line = np.ones(len(filterByYear))
scat = ax.scatter(filterByYear[series_name], y_line, c=filterByYear["cluster_color"], edgecolor='k', alpha=0.8)

# plot cluster centers (use the same color mapping: cluster center order corresponds to cluster indices)
center_x = y_pred.cluster_centers_[:, 1]  # your centers
center_colors = [cluster_color_map[i] for i in range(len(center_x))]
ax.scatter(center_x, np.ones(len(center_x)), marker='+', c="red", label="Center of Cluster")

# build manual legend for Low/Medium/High
handles = [mpatches.Patch(color=cluster_color_map[i], label=cluster_label_map[i]) for i in sorted(cluster_label_map)]
ax.legend(handles=handles + [plt.Line2D([0],[0], marker='+', color='red', label='Center of Cluster', linestyle='')],
          title="Labels",
          loc='upper right')

ax.set_xlabel("Number of beds")
ax.get_yaxis().set_ticks([])
plt.show()
